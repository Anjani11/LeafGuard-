# %%
# !pip install black
# Out:
# Requirement already satisfied: black in e:\softwares\lib\site-packages (21.12b0)
# Requirement already satisfied: click>=7.1.2 in e:\softwares\lib\site-packages (from black) (8.1.7)
# Requirement already satisfied: platformdirs>=2 in c:\users\katak\appdata\roaming\python\python311\site-packages (from black) (3.10.0)
# Requirement already satisfied: tomli<2.0.0,>=0.2.6 in e:\softwares\lib\site-packages (from black) (1.2.3)
# Requirement already satisfied: pathspec<1,>=0.9.0 in e:\softwares\lib\site-packages (from black) (0.12.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in e:\softwares\lib\site-packages (from black) (4.10.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in e:\softwares\lib\site-packages (from black) (1.0.0)
# Requirement already satisfied: colorama in e:\softwares\lib\site-packages (from click>=7.1.2->black) (0.4.6)

# %%
# !pip install blackcellmagic
# Out:
# Requirement already satisfied: blackcellmagic in e:\softwares\lib\site-packages (0.0.3)
# Requirement already satisfied: black<22.0,>=21.9b0 in e:\softwares\lib\site-packages (from blackcellmagic) (21.12b0)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in e:\softwares\lib\site-packages (from blackcellmagic) (1.0.0)
# Requirement already satisfied: click>=7.1.2 in e:\softwares\lib\site-packages (from black<22.0,>=21.9b0->blackcellmagic) (8.1.7)
# Requirement already satisfied: platformdirs>=2 in c:\users\katak\appdata\roaming\python\python311\site-packages (from black<22.0,>=21.9b0->blackcellmagic) (3.10.0)
# Requirement already satisfied: tomli<2.0.0,>=0.2.6 in e:\softwares\lib\site-packages (from black<22.0,>=21.9b0->blackcellmagic) (1.2.3)
# Requirement already satisfied: pathspec<1,>=0.9.0 in e:\softwares\lib\site-packages (from black<22.0,>=21.9b0->blackcellmagic) (0.12.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in e:\softwares\lib\site-packages (from black<22.0,>=21.9b0->blackcellmagic) (4.10.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in e:\softwares\lib\site-packages (from black<22.0,>=21.9b0->blackcellmagic) (1.0.0)
# Requirement already satisfied: notebook in e:\softwares\lib\site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (7.1.3)
# Requirement already satisfied: qtconsole in e:\softwares\lib\site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.5.1)
# Requirement already satisfied: jupyter-console in e:\softwares\lib\site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.6.3)
# Requirement already satisfied: nbconvert in e:\softwares\lib\site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (7.16.3)
# Requirement already satisfied: ipykernel in c:\users\katak\appdata\roaming\python\python311\site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.25.2)
# Requirement already satisfied: ipywidgets in e:\softwares\lib\site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (8.1.2)
# Requirement already satisfied: colorama in e:\softwares\lib\site-packages (from click>=7.1.2->black<22.0,>=21.9b0->blackcellmagic) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.7.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (8.3.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.5.7)
# Requirement already satisfied: packaging in e:\softwares\lib\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (23.1)
# Requirement already satisfied: psutil in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in e:\softwares\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->blackcellmagic) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in e:\softwares\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.0.10)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\katak\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.0.39)
# Requirement already satisfied: pygments in c:\users\katak\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.16.1)
# Requirement already satisfied: beautifulsoup4 in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.1.0)
# Requirement already satisfied: defusedxml in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.5.1)
# Requirement already satisfied: tinycss2 in e:\softwares\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in e:\softwares\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in e:\softwares\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.27.1)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in e:\softwares\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (4.1.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in e:\softwares\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in e:\softwares\lib\site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.4.1)
# Requirement already satisfied: six>=1.9.0 in e:\softwares\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.16.0)
# Requirement already satisfied: webencodings in e:\softwares\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.5.1)
# Requirement already satisfied: backcall in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.0)
# Requirement already satisfied: decorator in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.19.0)
# Requirement already satisfied: pickleshare in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\katak\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\softwares\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.8.2)
# Requirement already satisfied: pywin32>=300 in c:\users\katak\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (306)
# Requirement already satisfied: anyio>=3.1.0 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (4.3.0)
# Requirement already satisfied: argon2-cffi>=21.1 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in e:\softwares\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in e:\softwares\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in e:\softwares\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in e:\softwares\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.2.5)
# Requirement already satisfied: babel>=2.10 in e:\softwares\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in e:\softwares\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in e:\softwares\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (4.21.1)
# Requirement already satisfied: requests>=2.31 in e:\softwares\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.31.0)
# Requirement already satisfied: fastjsonschema>=2.15 in e:\softwares\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.19.1)
# Requirement already satisfied: wcwidth in c:\users\katak\appdata\roaming\python\python311\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.6)
# Requirement already satisfied: soupsieve>1.2 in e:\softwares\lib\site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.5)
# Requirement already satisfied: idna>=2.8 in e:\softwares\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.4)
# Requirement already satisfied: sniffio>=1.1 in e:\softwares\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in e:\softwares\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (21.2.0)
# Requirement already satisfied: certifi in e:\softwares\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in e:\softwares\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in e:\softwares\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\katak\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in e:\softwares\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\softwares\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\softwares\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.35.0)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\softwares\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.18.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in e:\softwares\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in e:\softwares\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.0.1)
# Requirement already satisfied: rfc3339-validator in e:\softwares\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in e:\softwares\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\softwares\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\softwares\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.0.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\katak\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\katak\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\katak\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.2)
# Requirement already satisfied: fqdn in e:\softwares\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.5.1)
# Requirement already satisfied: isoduration in e:\softwares\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in e:\softwares\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.4)
# Requirement already satisfied: uri-template in e:\softwares\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in e:\softwares\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in e:\softwares\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.15.1)
# Requirement already satisfied: pycparser in e:\softwares\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in e:\softwares\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in e:\softwares\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.9.0.20240316)

# %%
# %load_ext blackcellmagic

# %%
# !pip install nb_black-1.0.7.tar.gz
# Out:
# Processing e:\final year projects\leafguard\plant-disease-detection-main\model\nb_black-1.0.7.tar.gz
# WARNING: Requirement 'nb_black-1.0.7.tar.gz' looks like a filename, but the file does not exist
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'E:\\Final Year Projects\\leafguard\\Plant-Disease-Detection-main\\Model\\nb_black-1.0.7.tar.gz'

# %%
### Import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms, models
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn as nn
import torch.nn.functional as F
from datetime import datetime

# %load_ext nb_black

### Define compute_accuracy function
def compute_accuracy(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0

    with torch.no_grad():  # Disable gradient computation for efficiency
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    return accuracy

### Import Dataset
transform = transforms.Compose(
    [transforms.Resize(255), transforms.CenterCrop(224), transforms.ToTensor()]
)

dataset = datasets.ImageFolder("Dataset", transform=transform) 

indices = list(range(len(dataset)))

split = int(np.floor(0.85 * len(dataset)))  # train_size
validation = int(np.floor(0.70 * split))  # validation

print(0, validation, split, len(dataset))
print(f"length of train size :{validation}")
print(f"length of validation size :{split - validation}")
print(f"length of test size :{len(dataset)-validation}")

np.random.shuffle(indices)

### Split into Train and Test
train_indices, validation_indices, test_indices = (
    indices[:validation],
    indices[validation:split],
    indices[split:],
)

train_sampler = SubsetRandomSampler(train_indices)
validation_sampler = SubsetRandomSampler(validation_indices)
test_sampler = SubsetRandomSampler(test_indices)

targets_size = len(dataset.class_to_idx)

### Model
class CNN(nn.Module):
    def __init__(self, K):
        super(CNN, self).__init__()
        self.conv_layers = nn.Sequential(
            # conv1
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            # conv2
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            # conv3
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2),
            # conv4
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2),
        )

        self.dense_layers = nn.Sequential(
            nn.Dropout(0.4),
            nn.Linear(50176, 1024),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(1024, K),
        )

    def forward(self, X):
        out = self.conv_layers(X)

        # Flatten
        out = out.view(-1, 50176)

        # Fully connected
        out = self.dense_layers(out)

        return out

### Initialize device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

### Initialize model
model = CNN(targets_size).to(device)

### Initialize criterion and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

### Initialize data loaders
batch_size = 64
train_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=train_sampler
)
test_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=test_sampler
)
validation_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=validation_sampler
)

### Batch Gradient Descent
def batch_gd(model, criterion, train_loader, test_loader, epochs):
    train_losses = np.zeros(epochs)
    test_losses = np.zeros(epochs)

    for e in range(epochs):
        t0 = datetime.now()
        train_loss = []
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()

            output = model(inputs)

            loss = criterion(output, targets)

            train_loss.append(loss.item())  # torch to numpy world

            loss.backward()
            optimizer.step()

        train_loss = np.mean(train_loss)

        validation_loss = []

        for inputs, targets in validation_loader:

            inputs, targets = inputs.to(device), targets.to(device)

            output = model(inputs)

            loss = criterion(output, targets)

            validation_loss.append(loss.item())  # torch to numpy world

        validation_loss = np.mean(validation_loss)

        train_losses[e] = train_loss
        test_losses[e] = validation_loss

        dt = datetime.now() - t0

        print(
            f"Epoch : {e+1}/{epochs} Train_loss:{train_loss:.3f} Test_loss:{validation_loss:.3f} Duration:{dt}"
        )

    return train_losses, test_losses

### Train the model
train_losses, validation_losses = batch_gd(
    model, criterion, train_loader, validation_loader, 5
)

### Compute accuracies
train_accuracy = compute_accuracy(model, train_loader)
validation_accuracy = compute_accuracy(model, validation_loader)
test_accuracy = compute_accuracy(model, test_loader)

print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Validation Accuracy: {validation_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

### Plot the loss
plt.plot(train_losses, label="train_loss")
plt.plot(validation_losses, label="validation_loss")
plt.xlabel("No of Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 12
#       9 import torch.nn.functional as F
#      10 from datetime import datetime
# ---> 12 get_ipython().run_line_magic('load_ext', 'nb_black')
#      14 ### Define compute_accuracy function
#      15 def compute_accuracy(model, data_loader):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\extensions.py:76, in ExtensionManager.load_extension(self, module_str)
#      69 """Load an IPython extension by its module name.
#      70
#      71 Returns the string "already loaded" if the extension is already loaded,
#      72 "no load function" if the module doesn't have a load_ipython_extension
#      73 function, or None if it succeeded.
#      74 """
#      75 try:
# ---> 76     return self._load_extension(module_str)
#      77 except ModuleNotFoundError:
#      78     if module_str in BUILTINS_EXTS:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\extensions.py:91, in ExtensionManager._load_extension(self, module_str)
#      89 with self.shell.builtin_trap:
#      90     if module_str not in sys.modules:
# ---> 91         mod = import_module(module_str)
#      92     mod = sys.modules[module_str]
#      93     if self._call_load_ipython_extension(mod):
#
# File e:\softwares\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'nb_black'
